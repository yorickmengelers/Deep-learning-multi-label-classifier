# %%
# Simple PCA 
# youtube source: https://www.youtube.com/watch?v=QdBy02ExhGI
# second source: https://jakevdp.github.io/PythonDataScienceHandbook/05.09-principal-component-analysis.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data_RNAseq.csv', index_col=0)
data.head()
# Out:
#           gene_0    gene_1    gene_2    gene_3     gene_4  gene_5    gene_6  \
# sample_0     0.0  2.017209  3.265527  5.478487  10.431999     0.0  7.175175
# sample_1     0.0  0.592732  1.588421  7.586157   9.623011     0.0  6.816049
# sample_2     0.0  3.511759  4.327199  6.881787   9.870730     0.0  6.972130
# sample_3     0.0  3.663618  4.507649  6.659068  10.196184     0.0  7.843375
# sample_4     0.0  2.655741  2.821547  6.539454   9.738265     0.0  6.566967
#
#             gene_7  gene_8  gene_9  ...  gene_20521  gene_20522  gene_20523  \
# sample_0  0.591871     0.0     0.0  ...    4.926711    8.210257    9.723516
# sample_1  0.000000     0.0     0.0  ...    4.593372    7.323865    9.740931
# sample_2  0.452595     0.0     0.0  ...    5.125213    8.127123   10.908640
# sample_3  0.434882     0.0     0.0  ...    6.076566    8.792959   10.141520
# sample_4  0.360982     0.0     0.0  ...    5.996032    8.891425   10.373790
#
# ...

# %%
labels = pd.read_csv('labels_RNAseq.csv', index_col = 0)
labels
# Out:
#            Class
# sample_0    PRAD
# sample_1    LUAD
# sample_2    PRAD
# sample_3    PRAD
# sample_4    BRCA
# ...          ...
# sample_796  BRCA
# sample_797  LUAD
# sample_798  COAD
# sample_799  PRAD
# sample_800  PRAD
#
# [801 rows x 1 columns]

# %%
df = pd.DataFrame(data)
df
# Out:
#             gene_0    gene_1    gene_2    gene_3     gene_4  gene_5    gene_6  \
# sample_0       0.0  2.017209  3.265527  5.478487  10.431999     0.0  7.175175
# sample_1       0.0  0.592732  1.588421  7.586157   9.623011     0.0  6.816049
# sample_2       0.0  3.511759  4.327199  6.881787   9.870730     0.0  6.972130
# sample_3       0.0  3.663618  4.507649  6.659068  10.196184     0.0  7.843375
# sample_4       0.0  2.655741  2.821547  6.539454   9.738265     0.0  6.566967
# ...            ...       ...       ...       ...        ...     ...       ...
# sample_796     0.0  1.865642  2.718197  7.350099  10.006003     0.0  6.764792
# sample_797     0.0  3.942955  4.453807  6.346597  10.056868     0.0  7.320331
# sample_798     0.0  3.249582  3.707492  8.185901   9.504082     0.0  7.536589
# sample_799     0.0  2.590339  2.787976  7.318624   9.987136     0.0  9.213464
# sample_800     0.0  2.325242  3.805932  6.530246   9.560367     0.0  7.957027
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
scalar=StandardScaler()
scalar.fit(df)
# Out:
# StandardScaler()

# %%
scaled_data = scalar.transform(df)
scaled_data
# Out:
# array([[-0.19479935, -0.82802988,  0.15980044, ..., -1.18793812,
#         -0.11648251, -0.26190144],
#        [-0.19479935, -2.01501735, -1.415042  , ..., -0.34227662,
#         -1.65688871, -0.26190144],
#        [-0.19479935,  0.41734754,  1.15673547, ...,  0.88686027,
#         -1.85526414, -0.26190144],
#        ...,
#        [-0.19479935,  0.19888076,  0.57481583, ..., -0.22008186,
#         -0.41046699,  1.3485582 ],
#        [-0.19479935, -0.35045311, -0.28863152, ...,  1.43719268,
#          0.09195083, -0.26190144],
#        [-0.19479935, -0.57135218,  0.66725377, ...,  0.45087581,
#         -0.47161901, -0.26190144]])

# %%
from sklearn.decomposition import PCA

# %%
scaled_data.shape
# Out:
# (801, 20531)

# %%
pca = PCA()
pca_n2 = PCA(n_components=2)
pca_n5 = PCA(n_components= 5)
pca_n10 = PCA(n_components= 10)
pca_n25 = PCA(n_components= 25)

# %%
pca.fit(scaled_data)
pca_n2.fit(scaled_data)
pca_n5.fit(scaled_data)
pca_n10.fit(scaled_data)
pca_n25.fit(scaled_data)
# Out:
# PCA(n_components=25)

# %%
x_pca = pca.transform(scaled_data)
x_pca_n2 = pca_n2.transform(scaled_data)
x_pca_n5 = pca_n5.transform(scaled_data)
x_pca_n10 = pca_n10.transform(scaled_data)
x_pca_n25 = pca_n10.transform(scaled_data)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
x_pca_n2.explaied
# Out:
# (801, 10)

# %%
# make labels numeric see cell below 
labels['Class'].unique()
labels['Class'] = labels['Class'].astype('category').cat.codes

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca_n2[:, 0], x_pca_n2[:,1], c= labels['Class'] )
